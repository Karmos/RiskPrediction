# %% [markdown]
# Struttura del notebook
#
# 3. Suddivisione e Scaling
#     - Separazione dei dati in set di addestramento e test.
#     - Standardizzazione dei dati numerici.
#     - Controllo della suddivisione e scaling.
#
# 4. Addestramento e Valutazione del Modello
#     - Selezione e addestramento del modello (e.g., Random Forest, Regressione Logistica).
#     - Valutazione delle performance del modello (accuratezza, precisione, recall).
#     - Tuning degli iperparametri.
#
# 5. Conclusioni e Passi Successivi
#     - Riepilogo dei risultati e performance.
#     - Conclusioni.

# %% [markdown]
# ## Install and Import Libraries

# %%
# !pip install pandas numpy scikit-learn imblearn seaborn shap matplotlib xgboost scipy pickle

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, precision_score, recall_score, f1_score, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
import numpy as np
import pandas as pd
import seaborn as sns
import shap
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# # Split Data & Scaling

# %%
dataset_path = '../dataset/preprocessed_data.csv'
df = pd.read_csv(dataset_path)

X = df.drop(columns=['risk_level'])
y = df['risk_level']

# %%
# Eseguiamo il primo train-test split con stratificazione per ottenere il 10% dei dati

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# Si scala le caratteristiche in modo che siano normalizzate con media zero. Questo passaggio è consigliato per le SVM e modelli lineari, poiché facilita l'adattamento del modello. Considerata la presenza di outlier, si è optato per utilizzare uno StandardScaler anziché un MinMaxScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)

# %% [markdown]
# ## Bilanciamento con UnderSampling

# %%
print("\nDistribuzione delle classi prima di SMOTE:")
print(Counter(y_train))
# Out:
# Distribuzione delle classi prima di SMOTE:
# Counter({0.0: 663396, 1.0: 37174})

# %%
undSampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
X_train, y_train = undSampler.fit_resample(X_train, y_train)

# %%
print("\nDistribuzione delle classi dopo SMOTE:")
print(Counter(y_train))
# Out:
# Distribuzione delle classi dopo SMOTE:
# Counter({0.0: 37174, 1.0: 37174})

# %% [markdown]
# ## Correlation

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv      term  \
# loan_amnt                    1.000000     0.999422         0.975037  0.425341
# funded_amnt                  0.999422     1.000000         0.975794  0.424549
# funded_amnt_inv              0.975037     0.975794         1.000000  0.411118
# term                         0.425341     0.424549         0.411118  1.000000
# int_rate                     0.126403     0.126679         0.145761  0.428490
# installment                  0.962657     0.963531         0.935050  0.196233
# sub_grade                   -0.138916    -0.138826        -0.157769 -0.454685
# annual_inc                   0.312712     0.312503         0.332125  0.058702
# verification_status          0.271784     0.271722         0.280681  0.195266
# dti                          0.048787     0.049544         0.045123  0.106791
# delinq_2yrs                 -0.001121    -0.000830         0.000860 -0.000279
# inq_last_6mths              -0.030770    -0.031072        -0.029545 -0.000712
# open_acc                     0.200448     0.200876         0.199466  0.086080
# pub_rec                     -0.079402    -0.079072        -0.080811 -0.025603
# revol_bal                    0.317415     0.317270         0.336339  0.093304
# revol_util                   0.119513     0.119994         0.120526  0.085360
# total_acc                    0.221060     0.221025         0.222490  0.101981
# initial_list_status          0.091554     0.092964         0.089154  0.132337
# out_prncp                    0.623468     0.625031         0.648577  0.394725
# out_prncp_inv                0.623470     0.625034         0.648589  0.394681
# total_pymnt                  0.474581     0.473525         0.475437  0.084156
# total_pymnt_inv              0.475164     0.474273         0.479377  0.085234
# total_rec_prncp              0.394309     0.393324         0.390049 -0.025869
# total_rec_int                0.520144     0.519366         0.536538  0.386088
# total_rec_late_fee           0.028698     0.028435         0.030973  0.006181
# recoveries                   0.071147     0.070794         0.072570  0.058156
# collection_recovery_fee      0.051397     0.051178         0.052253  0.037272
# last_pymnt_amnt              0.227281     0.226931         0.229266  0.071701
# collections_12_mths_ex_med  -0.016114    -0.015967        -0.016226 -0.005418
# acc_now_delinq               0.003506     0.003598         0.004177  0.005003
# tot_coll_amt                -0.003824    -0.003825        -0.004092 -0.002206
# tot_cur_bal                  0.304562     0.304611         0.324159  0.111244
# total_rev_hi_lim             0.301284     0.301247         0.315559  0.067967
# home_ownership_ANY           0.001020     0.001022         0.001400  0.000132
# home_ownership_MORTGAGE      0.189800     0.189642         0.191690  0.108776
# home_ownership_NONE         -0.000355    -0.000345        -0.000774 -0.002267
# home_ownership_OTHER        -0.004410    -0.005053        -0.007999 -0.007048
# home_ownership_OWN          -0.021861    -0.021695        -0.020400 -0.015031
# home_ownership_RENT         -0.180196    -0.180120        -0.182914 -0.101602
# purpose_car                 -0.077897    -0.077972        -0.069984 -0.018520
# purpose_credit_card          0.046924     0.047294         0.038592 -0.035963
# purpose_debt_consolidation   0.113983     0.114238         0.095749  0.074909
# purpose_educational         -0.022139    -0.022440        -0.020871 -0.010585
# purpose_home_improvement    -0.019375    -0.019542        -0.013003  0.005002
# purpose_house               -0.000080    -0.000253         0.000435 -0.000579
# purpose_major_purchase      -0.064470    -0.064721        -0.052881 -0.016610
# purpose_medical             -0.078643    -0.078693        -0.066795 -0.024689
# purpose_moving              -0.076403    -0.076479        -0.063702 -0.027660
# purpose_other               -0.153322    -0.153564        -0.129647 -0.046018
# purpose_renewable_energy    -0.017649    -0.017733        -0.014910 -0.006774
# purpose_small_business       0.005338     0.004407         0.005126 -0.005983
# purpose_vacation            -0.091379    -0.091394        -0.073297 -0.034216
# purpose_wedding             -0.027198    -0.027553        -0.027416 -0.014658
# risk_level                  -0.005724    -0.006504        -0.008697  0.030018
#
#                             int_rate  installment  sub_grade  annual_inc  \
# loan_amnt                   0.126403     0.962657  -0.138916    0.312712
# funded_amnt                 0.126679     0.963531  -0.138826    0.312503
# funded_amnt_inv             0.145761     0.935050  -0.157769    0.332125
# term                        0.428490     0.196233  -0.454685    0.058702
# int_rate                    1.000000     0.123954  -0.978592   -0.072729
# installment                 0.123954     1.000000  -0.126621    0.305985
# sub_grade                  -0.978592    -0.126621   1.000000    0.065883
# annual_inc                 -0.072729     0.305985   0.065883    1.000000
# verification_status         0.218977     0.258448  -0.224829    0.084170
# dti                         0.163685     0.039895  -0.176943   -0.177901
# delinq_2yrs                 0.055542     0.006089  -0.061743    0.047680
# inq_last_6mths              0.232196    -0.003410  -0.218670    0.037203
# open_acc                   -0.010401     0.188210   0.000514    0.137746
# pub_rec                     0.052176    -0.069618  -0.061939   -0.008600
# revol_bal                  -0.035789     0.303255   0.029915    0.295369
# revol_util                  0.269840     0.134687  -0.256959    0.036591
# total_acc                  -0.038868     0.201422   0.034974    0.186600
# initial_list_status        -0.114122     0.042985   0.065908    0.037947
# out_prncp                   0.043465     0.545273  -0.123288    0.211108
# out_prncp_inv               0.043325     0.545270  -0.123146    0.211148
# total_pymnt                 0.170530     0.509050  -0.090138    0.162332
# total_pymnt_inv             0.171619     0.509637  -0.089827    0.162383
# total_rec_prncp             0.053877     0.443220   0.022849    0.151209
# total_rec_int               0.448333     0.494582  -0.391982    0.129552
# total_rec_late_fee          0.057400     0.036237  -0.052667    0.013673
# recoveries                  0.107649     0.072561  -0.093668    0.007573
# collection_recovery_fee     0.072182     0.053121  -0.065375    0.006750
# last_pymnt_amnt             0.101170     0.236106  -0.068962    0.091579
# collections_12_mths_ex_med  0.013457    -0.013708  -0.020513   -0.003706
# acc_now_delinq              0.026603     0.005760  -0.029040    0.014721
# tot_coll_amt                0.001098    -0.003205  -0.001878    0.001146
# tot_cur_bal                -0.085756     0.278060   0.081353    0.410747
# total_rev_hi_lim           -0.149741     0.280405   0.139688    0.270612
# home_ownership_ANY          0.000415     0.001084  -0.000492   -0.000323
# home_ownership_MORTGAGE    -0.061237     0.161615   0.063102    0.155333
# home_ownership_NONE         0.002923     0.000793  -0.001095   -0.001270
# home_ownership_OTHER       -0.000293    -0.003198   0.000547   -0.001317
# home_ownership_OWN          0.001942    -0.018584  -0.006408   -0.031222
# home_ownership_RENT         0.061245    -0.153488  -0.060467   -0.139412
# purpose_car                -0.028551    -0.081232   0.028042   -0.011089
# purpose_credit_card        -0.184899     0.039927   0.188150    0.000451
# purpose_debt_consolidation  0.097189     0.115605  -0.096414   -0.021026
# purpose_educational        -0.007042    -0.022175   0.005374   -0.006418
# purpose_home_improvement   -0.012458    -0.024560   0.009708    0.058688
# purpose_house               0.041155     0.004953  -0.041074    0.005586
# purpose_major_purchase     -0.018545    -0.067910   0.017251    0.003889
# purpose_medical             0.029716    -0.076185  -0.031002   -0.004195
# purpose_moving              0.044577    -0.071845  -0.046129   -0.008150
# purpose_other               0.092117    -0.144862  -0.094443   -0.018477
# purpose_renewable_energy    0.012575    -0.016172  -0.013124   -0.000617
# purpose_small_business      0.073992     0.016014  -0.076741    0.024408
# purpose_vacation            0.018686    -0.089781  -0.019231   -0.009128
# purpose_wedding             0.010435    -0.024011  -0.005821   -0.004319
# risk_level                  0.149432     0.003197  -0.121690   -0.036183
#
#                             verification_status       dti  ...  purpose_house  \
# loan_amnt                              0.271784  0.048787  ...      -0.000080
# funded_amnt                            0.271722  0.049544  ...      -0.000253
# funded_amnt_inv                        0.280681  0.045123  ...       0.000435
# term                                   0.195266  0.106791  ...      -0.000579
# int_rate                               0.218977  0.163685  ...       0.041155
# installment                            0.258448  0.039895  ...       0.004953
# sub_grade                             -0.224829 -0.176943  ...      -0.041074
# annual_inc                             0.084170 -0.177901  ...       0.005586
# verification_status                    1.000000  0.072563  ...       0.007533
# dti                                    0.072563  1.000000  ...      -0.029192
# delinq_2yrs                            0.007529 -0.008300  ...       0.003061
# inq_last_6mths                         0.052307 -0.012696  ...       0.023758
# open_acc                               0.034228  0.300293  ...      -0.013513
# pub_rec                                0.053242 -0.046971  ...       0.001891
# revol_bal                              0.083157  0.141520  ...      -0.016354
# revol_util                             0.083663  0.179489  ...      -0.036887
# total_acc                              0.047804  0.225088  ...      -0.008926
# initial_list_status                    0.013760  0.047933  ...      -0.018247
# out_prncp                              0.176203  0.120007  ...      -0.018794
# out_prncp_inv                          0.176163  0.119931  ...      -0.018803
# total_pymnt                            0.148380 -0.082352  ...       0.021677
# total_pymnt_inv                        0.150529 -0.080334  ...       0.021397
# total_rec_prncp                        0.104154 -0.104691  ...       0.021813
# total_rec_int                          0.220376  0.021282  ...       0.011038
# total_rec_late_fee                     0.010972 -0.010261  ...       0.005496
# recoveries                             0.036103  0.003509  ...       0.006826
# collection_recovery_fee                0.024319  0.006028  ...       0.002053
# last_pymnt_amnt                        0.076626 -0.059488  ...       0.019571
# collections_12_mths_ex_med             0.021325 -0.000400  ...       0.000940
# acc_now_delinq                         0.013715  0.006908  ...       0.000422
# tot_coll_amt                           0.001487 -0.004384  ...       0.000557
# tot_cur_bal                            0.048181 -0.005468  ...      -0.012228
# total_rev_hi_lim                       0.048399  0.084608  ...      -0.009500
# home_ownership_ANY                     0.001209  0.001897  ...      -0.000119
# home_ownership_MORTGAGE                0.008326 -0.010411  ...      -0.021186
# home_ownership_NONE                   -0.001578  0.000558  ...      -0.000462
# home_ownership_OTHER                  -0.005623 -0.005849  ...       0.000560
# home_ownership_OWN                     0.004548  0.032133  ...       0.006090
# home_ownership_RENT                   -0.011092 -0.008773  ...       0.017901
# purpose_car                           -0.033000 -0.045195  ...      -0.006466
# purpose_credit_card                   -0.033506  0.012736  ...      -0.035497
# purpose_debt_consolidation             0.050876  0.092394  ...      -0.077598
# purpose_educational                   -0.017252 -0.016044  ...      -0.001244
# purpose_home_improvement              -0.006825 -0.077540  ...      -0.016052
# purpose_house                          0.007533 -0.029192  ...       1.000000
# purpose_major_purchase                -0.024601 -0.059916  ...      -0.009064
# purpose_medical                       -0.013693 -0.010793  ...      -0.006342
# purpose_moving                        -0.010680 -0.018553  ...      -0.005039
# purpose_other                         -0.010747 -0.034582  ...      -0.014466
# purpose_renewable_energy               0.000820 -0.007374  ...      -0.001640
# purpose_small_business                 0.028718 -0.053310  ...      -0.006966
# purpose_vacation                      -0.010385 -0.008682  ...      -0.004716
# purpose_wedding                       -0.011936 -0.025457  ...      -0.003302
# risk_level                             0.015774  0.009063  ...       0.007981
#
#                             purpose_major_purchase  purpose_medical  \
# loan_amnt                                -0.064470        -0.078643
# funded_amnt                              -0.064721        -0.078693
# funded_amnt_inv                          -0.052881        -0.066795
# term                                     -0.016610        -0.024689
# int_rate                                 -0.018545         0.029716
# installment                              -0.067910        -0.076185
# sub_grade                                 0.017251        -0.031002
# annual_inc                                0.003889        -0.004195
# verification_status                      -0.024601        -0.013693
# dti                                      -0.059916        -0.010793
# delinq_2yrs                               0.000106         0.004888
# inq_last_6mths                            0.015261         0.006669
# open_acc                                 -0.037348        -0.014716
# pub_rec                                   0.000384         0.005359
# revol_bal                                -0.033110        -0.015941
# revol_util                               -0.076390        -0.020566
# total_acc                                -0.032392        -0.009228
# initial_list_status                      -0.015997        -0.010701
# out_prncp                                -0.036465        -0.041867
# out_prncp_inv                            -0.036473        -0.041862
# total_pymnt                              -0.023891        -0.033433
# total_pymnt_inv                          -0.024225        -0.033565
# total_rec_prncp                          -0.018456        -0.030133
# total_rec_int                            -0.030901        -0.029844
# total_rec_late_fee                        0.002417         0.001573
# recoveries                               -0.002023        -0.001736
# collection_recovery_fee                  -0.002206        -0.000995
# last_pymnt_amnt                          -0.010340        -0.014306
# collections_12_mths_ex_med                0.001732         0.000338
# acc_now_delinq                            0.002029         0.001357
# tot_coll_amt                              0.000794         0.000867
# tot_cur_bal                              -0.017261        -0.009893
# total_rev_hi_lim                         -0.017432        -0.014750
# home_ownership_ANY                       -0.000260        -0.000182
# home_ownership_MORTGAGE                  -0.021828        -0.010146
# home_ownership_NONE                      -0.001008        -0.000705
# home_ownership_OTHER                      0.002720         0.001482
# home_ownership_OWN                        0.008440         0.002995
# home_ownership_RENT                       0.017080         0.008501
# purpose_car                              -0.014095        -0.009861
# purpose_credit_card                      -0.077383        -0.054141
# purpose_debt_consolidation               -0.169162        -0.118354
# purpose_educational                      -0.002713        -0.001898
# purpose_home_improvement                 -0.034992        -0.024482
# purpose_house                            -0.009064        -0.006342
# purpose_major_purchase                    1.000000        -0.013824
# purpose_medical                          -0.013824         1.000000
# purpose_moving                           -0.010984        -0.007685
# purpose_other                            -0.031536        -0.022064
# purpose_renewable_energy                 -0.003575        -0.002501
# purpose_small_business                   -0.015185        -0.010624
# purpose_vacation                         -0.010280        -0.007193
# purpose_wedding                          -0.007199        -0.005037
# risk_level                               -0.000457         0.007263
#
#                             purpose_moving  purpose_other  \
# loan_amnt                        -0.076403      -0.153322
# funded_amnt                      -0.076479      -0.153564
# funded_amnt_inv                  -0.063702      -0.129647
# term                             -0.027660      -0.046018
# int_rate                          0.044577       0.092117
# installment                      -0.071845      -0.144862
# sub_grade                        -0.046129      -0.094443
# annual_inc                       -0.008150      -0.018477
# verification_status              -0.010680      -0.010747
# dti                              -0.018553      -0.034582
# delinq_2yrs                       0.003864       0.007604
# inq_last_6mths                    0.006626       0.009997
# open_acc                         -0.017530      -0.052462
# pub_rec                          -0.001504       0.007904
# revol_bal                        -0.021046      -0.043336
# revol_util                       -0.014086      -0.037153
# total_acc                        -0.020064      -0.048727
# initial_list_status              -0.017558      -0.035186
# out_prncp                        -0.041426      -0.083813
# out_prncp_inv                    -0.041419      -0.083794
# total_pymnt                      -0.030255      -0.059589
# total_pymnt_inv                  -0.030306      -0.060318
# total_rec_prncp                  -0.027287      -0.056225
# total_rec_int                    -0.026913      -0.045710
# total_rec_late_fee                0.005449       0.005758
# recoveries                       -0.001796      -0.000701
# collection_recovery_fee          -0.001448      -0.001993
# last_pymnt_amnt                  -0.012935      -0.027763
# collections_12_mths_ex_med        0.000320       0.001800
# acc_now_delinq                    0.000830       0.002194
# tot_coll_amt                     -0.000065       0.005584
# tot_cur_bal                      -0.026023      -0.035928
# total_rev_hi_lim                 -0.019753      -0.043401
# home_ownership_ANY               -0.000145       0.002473
# home_ownership_MORTGAGE          -0.051782      -0.046984
# home_ownership_NONE              -0.000560      -0.000117
# home_ownership_OTHER              0.000144       0.002960
# home_ownership_OWN               -0.011166       0.009632
# home_ownership_RENT               0.059610       0.041985
# purpose_car                      -0.007836      -0.022496
# purpose_credit_card              -0.043018      -0.123505
# purpose_debt_consolidation       -0.094040      -0.269985
# purpose_educational              -0.001508      -0.004329
# purpose_home_improvement         -0.019453      -0.055848
# purpose_house                    -0.005039      -0.014466
# purpose_major_purchase           -0.010984      -0.031536
# purpose_medical                  -0.007685      -0.022064
# purpose_moving                    1.000000      -0.017531
# purpose_other                    -0.017531       1.000000
# purpose_renewable_energy         -0.001987      -0.005705
# purpose_small_business           -0.008442      -0.024236
# purpose_vacation                 -0.005715      -0.016408
# purpose_wedding                  -0.004002      -0.011490
# risk_level                        0.010099       0.018467
#
#                             purpose_renewable_energy  purpose_small_business  \
# loan_amnt                                  -0.017649                0.005338
# funded_amnt                                -0.017733                0.004407
# funded_amnt_inv                            -0.014910                0.005126
# term                                       -0.006774               -0.005983
# int_rate                                    0.012575                0.073992
# installment                                -0.016172                0.016014
# sub_grade                                  -0.013124               -0.076741
# annual_inc                                 -0.000617                0.024408
# verification_status                         0.000820                0.028718
# dti                                        -0.007374               -0.053310
# delinq_2yrs                                -0.001402                0.001576
# inq_last_6mths                              0.003098                0.029831
# open_acc                                   -0.007088               -0.031097
# pub_rec                                     0.001129                0.010713
# revol_bal                                  -0.004332               -0.011579
# revol_util                                 -0.004296               -0.042130
# total_acc                                  -0.005706               -0.022791
# initial_list_status                        -0.008553               -0.039436
# out_prncp                                  -0.012614               -0.028033
# out_prncp_inv                              -0.012610               -0.028031
# total_pymnt                                -0.003856                0.035392
# total_pymnt_inv                            -0.004250                0.033000
# total_rec_prncp                            -0.003286                0.027556
# total_rec_int                              -0.004705                0.040262
# total_rec_late_fee                          0.001008                0.024176
# recoveries                                  0.003204                0.027572
# collection_recovery_fee                     0.003743                0.018553
# last_pymnt_amnt                            -0.002104                0.007306
# collections_12_mths_ex_med                 -0.000371                0.000829
# acc_now_delinq                             -0.001059               -0.001041
# tot_coll_amt                               -0.000033                0.001187
# tot_cur_bal                                -0.004532               -0.002623
# total_rev_hi_lim                           -0.004666               -0.007386
# home_ownership_ANY                         -0.000047               -0.000200
# home_ownership_MORTGAGE                    -0.004578               -0.007744
# home_ownership_NONE                        -0.000182               -0.000774
# home_ownership_OTHER                        0.003178                0.007789
# home_ownership_OWN                          0.002455               -0.001096
# home_ownership_RENT                         0.003098                0.008373
# purpose_car                                -0.002550               -0.010832
# purpose_credit_card                        -0.014000               -0.059471
# purpose_debt_consolidation                 -0.030605               -0.130005
# purpose_educational                        -0.000491               -0.002085
# purpose_home_improvement                   -0.006331               -0.026893
# purpose_house                              -0.001640               -0.006966
# purpose_major_purchase                     -0.003575               -0.015185
# purpose_medical                            -0.002501               -0.010624
# purpose_moving                             -0.001987               -0.008442
# purpose_other                              -0.005705               -0.024236
# purpose_renewable_energy                    1.000000               -0.002747
# purpose_small_business                     -0.002747                1.000000
# purpose_vacation                           -0.001860               -0.007901
# purpose_wedding                            -0.001302               -0.005533
# risk_level                                  0.004804                0.040740
#
#                             purpose_vacation  purpose_wedding  risk_level
# loan_amnt                          -0.091379        -0.027198   -0.005724
# funded_amnt                        -0.091394        -0.027553   -0.006504
# funded_amnt_inv                    -0.073297        -0.027416   -0.008697
# term                               -0.034216        -0.014658    0.030018
# int_rate                            0.018686         0.010435    0.149432
# installment                        -0.089781        -0.024011    0.003197
# sub_grade                          -0.019231        -0.005821   -0.121690
# annual_inc                         -0.009128        -0.004319   -0.036183
# verification_status                -0.010385        -0.011936    0.015774
# dti                                -0.008682        -0.025457    0.009063
# delinq_2yrs                         0.000796        -0.004722   -0.009761
# inq_last_6mths                      0.006440         0.011311    0.072471
# open_acc                           -0.015388        -0.017883   -0.021641
# pub_rec                             0.001738        -0.012400   -0.019555
# revol_bal                          -0.018750        -0.014744   -0.020161
# revol_util                         -0.016862        -0.017513    0.043080
# total_acc                          -0.012692        -0.021879   -0.020836
# initial_list_status                -0.011724        -0.041271   -0.097429
# out_prncp                          -0.043797        -0.047246   -0.225366
# out_prncp_inv                      -0.043802        -0.047253   -0.225365
# total_pymnt                        -0.038536         0.023743   -0.038239
# total_pymnt_inv                    -0.038548         0.022324   -0.039260
# total_rec_prncp                    -0.034360         0.024411   -0.088415
# total_rec_int                      -0.035169         0.010538    0.043133
# total_rec_late_fee                  0.000514         0.005866    0.119667
# recoveries                         -0.004085         0.007023    0.475976
# collection_recovery_fee            -0.003035         0.005647    0.330955
# last_pymnt_amnt                    -0.018566         0.004538   -0.085116
# collections_12_mths_ex_med         -0.001253        -0.005305   -0.010659
# acc_now_delinq                     -0.001680        -0.003009   -0.003250
# tot_coll_amt                        0.000216        -0.000254   -0.001729
# tot_cur_bal                        -0.017465        -0.014169   -0.036951
# total_rev_hi_lim                   -0.017618        -0.014604   -0.034623
# home_ownership_ANY                 -0.000135        -0.000095   -0.000438
# home_ownership_MORTGAGE            -0.020849        -0.019104   -0.029071
# home_ownership_NONE                -0.000524        -0.000367    0.003278
# home_ownership_OTHER               -0.000938         0.001087    0.007691
# home_ownership_OWN                  0.003442        -0.005744   -0.007517
# home_ownership_RENT                 0.019206         0.022955    0.033973
# purpose_car                        -0.007333        -0.005135   -0.000233
# purpose_credit_card                -0.040261        -0.028194   -0.033136
# purpose_debt_consolidation         -0.088012        -0.061634    0.009346
# purpose_educational                -0.001411        -0.000988    0.010220
# purpose_home_improvement           -0.018206        -0.012749   -0.008596
# purpose_house                      -0.004716        -0.003302    0.007981
# purpose_major_purchase             -0.010280        -0.007199   -0.000457
# purpose_medical                    -0.007193        -0.005037    0.007263
# purpose_moving                     -0.005715        -0.004002    0.010099
# purpose_other                      -0.016408        -0.011490    0.018467
# purpose_renewable_energy           -0.001860        -0.001302    0.004804
# purpose_small_business             -0.007901        -0.005533    0.040740
# purpose_vacation                    1.000000        -0.003746    0.002156
# purpose_wedding                    -0.003746         1.000000    0.014305
# risk_level                          0.002156         0.014305    1.000000
#
# [54 rows x 54 columns]

# %% [markdown]
# Alta correlazione tra molte delle caratteristiche è un'indicazione che l'uso di tecniche di riduzione della dimensionalità potrebbe essere vantaggioso.

# %% [markdown]
# # Feature Reduction

# %%
pca = PCA(n_components=len(X_train.columns))
pca.fit(X_train)
# Out:
# PCA(n_components=53)

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

# %%
# Create a DataFrame for cumulative explained variance ratio
cvr = pd.DataFrame({
    'Number of Principal Components': range(1, len(cumulative_variance) + 1),
    'Cumulative Explained Variance Ratio': cumulative_variance
})

# Set up the figure
plt.figure(figsize=(10, 6))

# Create the line plot using Seaborn
sns.lineplot(data=cvr, 
             x='Number of Principal Components', 
             y='Cumulative Explained Variance Ratio', 
             marker='o')  # Adding markers for clarity

# Add title and labels
plt.title('Cumulative Explained Variance Ratio by Number of Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance Ratio')

# Add grid lines for better readability
plt.grid(True)

# Show the figure
plt.show()

# %%
components_to_retain = np.argmax(cumulative_variance >= 0.9) + 1
pca = PCA(n_components=components_to_retain)

X_train = pca.fit_transform(X_train)

X_test_copy = X_test

X_test = pca.transform(X_test)
components_to_retain
# Out:
# 29

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Funzioni di utilità

# %%
def save_model(model, filename):
    filename = './models'+'/'+filename
    try:
        with open(filename, 'wb') as file:
            pickle.dump(model, file)
        print(f"Modello salvato con successo in: {filename}")
    except Exception as e:
        print(f"Errore nel salvataggio del modello: {e}")

# %%
def save_grid_search_results(results, columns_to_save, filename):
    filename = '../results'+'/'+filename

    # Seleziona le colonne principali per il CSV
    results_to_save = results[columns_to_save].copy()

    # Identifica il miglior modello basato su mean_test_score
    best_index = results['mean_test_score'].idxmax()  # Indice del miglior punteggio medio

    # Aggiungi una colonna che indica se il modello è il migliore
    results_to_save['is_best_model'] = False
    results_to_save.loc[best_index, 'is_best_model'] = True


    # Salva i risultati in un file CSV
    results_to_save.to_csv(filename, index=False)
    print(f"Risultati salvati con successo in: {filename}")

# %%
def plot_confusion_matrix(y_true, y_pred):
    # Calcola la matrice di confusione
    cm = confusion_matrix(y_true, y_pred)

    # Configura la visualizzazione
    plt.figure(figsize=(8,6))
    class_labels = sorted(set(y_true) | set(y_pred))  # Unisce le classi uniche di y_true e y_pred
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)

    # Aggiungi titolo e etichette
    plt.title('Confusion Matrix', fontsize=14)
    plt.xlabel('Predicted Labels', fontsize=12)
    plt.ylabel('True Labels', fontsize=12)

    # Mostra il grafico
    plt.show()

# %%
def plot_feature_importance(model, pca, X):
    importances = model.feature_importances_
    pca_loadings = pca.components_

    # The importance of each feature is the sum of the absolute values of its loadings across all components
    feature_importance = np.sum(np.abs(pca_loadings), axis=0)

    # Step 8: Sort the feature importances in descending order
    sorted_idx = np.argsort(feature_importance)[::-1]

    top_sorted_idx = sorted_idx[:28]

    # Step 10: Plot the top 28 feature importances based on original feature names
    plt.figure(figsize=(12, 6))
    plt.bar(range(28), feature_importance[top_sorted_idx])
    plt.title(f'Top {28} Feature Importance')
    plt.xlabel('Feature')
    plt.ylabel('Importance')
    plt.xticks(range(28), np.array(X.columns)[top_sorted_idx], rotation=90)  # If X is a DataFrame
    plt.show()

# %% [markdown]
# ### SVM

# %%
#Creo il classificatore SVM
svm = SVC(random_state=42)

# Definisco la griglia di iperparametri
param_grid = {
    'C': [1],                    # Ridotto ai valori più comuni per C
    'kernel': ['linear', 'rbf'], # Mantenuto solo il kernel lineare per semplificare
}

# Utilizzo il Grid Search
grid_search = GridSearchCV(estimator=svm, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

#  Miglior modello trovato
print("Migliori parametri trovati: ", grid_search.best_params_)
best_svm_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# Migliori parametri trovati:  {'C': 1, 'kernel': 'linear'}

# %%
# Predico sul set di test
y_pred = best_svm_model.predict(X_test)

#  Report di classificazione
print("Classification report on test set:")
print(classification_report(y_test, y_pred))
# Out:
# Classification report on test set:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99    165850
#          1.0       0.84      0.94      0.89      9293
#
#     accuracy                           0.99    175143
#    macro avg       0.92      0.96      0.94    175143
# weighted avg       0.99      0.99      0.99    175143

# %%
#  Matrice di confusione
plot_confusion_matrix(y_test, y_pred)

# %%
#Salvataggio dei risultati
columns_to_save = [
    'param_C', 'param_kernel', # Parametri del modello
    'mean_test_score', 'std_test_score', 'rank_test_score', 'precision', 'recall', 'f1_score', 'accuracy'
]

results = pd.DataFrame(grid_search.cv_results_)
results['precision'] = precision_score(y_test, y_pred, average='weighted')
results['recall'] = recall_score(y_test, y_pred, average='weighted')
results['f1_score'] = f1_score(y_test, y_pred, average='weighted')
results['accuracy'] = accuracy_score(y_test, y_pred)

save_grid_search_results(results, columns_to_save, 'svm_results.csv')

# Salvataggio del miglior modello SVM
save_model(best_svm_model, "best_svm_model.pkl")
# Out:
# Risultati salvati con successo in: ../results/svm_results.csv
# Errore nel salvataggio del modello: [Errno 2] No such file or directory: './models/best_svm_model.pkl'

# %% [markdown]
# ### Logistic Regression

# %%
# Creo il modello Logistic Regression
lr = LogisticRegression(random_state=42, max_iter=500)

# Definisco la griglia di iperparametri
param_grid = {
    'penalty': ['l2'],        # Limitato ai tipi di penalizzazione più comuni
    'C': [0.1, 1, 10],                # Ridotto l'intervallo di valori per C
    'solver': ['lbfgs', 'liblinear'], # Meno solver per velocizzare la ricerca
}

# Grid Search
grid_search = GridSearchCV(
    estimator=lr,
    param_grid=param_grid,
    scoring='f1_weighted',  # Ottimizzare per F1-score ponderato
    cv=5,
    n_jobs=-1,
    verbose=2
)
grid_search.fit(X_train, y_train)

# Miglior modello trovato
print("Migliori parametri trovati: ", grid_search.best_params_)
best_lr_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Migliori parametri trovati:  {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
# Predizioni sul set di test
y_pred = best_lr_model.predict(X_test)

# Report di classificazione
print("Classification report on test set:")
print(classification_report(y_test, y_pred))
# Out:
# Classification report on test set:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99    165850
#          1.0       0.81      0.94      0.87      9293
#
#     accuracy                           0.99    175143
#    macro avg       0.90      0.97      0.93    175143
# weighted avg       0.99      0.99      0.99    175143

# %%
#  Matrice di confusione
plot_confusion_matrix(y_test, y_pred)

# %%
#Salvataggio dei risultati
columns_to_save = [
    'param_penalty', 'param_C', 'param_solver',                   # Parametri del modello
    'mean_test_score', 'std_test_score', 'rank_test_score', 'precision', 'recall', 'f1_score', 'accuracy'
]

results = pd.DataFrame(grid_search.cv_results_)
results['precision'] = precision_score(y_test, y_pred, average='weighted')
results['recall'] = recall_score(y_test, y_pred, average='weighted')
results['f1_score'] = f1_score(y_test, y_pred, average='weighted')
results['accuracy'] = accuracy_score(y_test, y_pred)

save_grid_search_results(results, columns_to_save, 'lr_results.csv')

# Salvataggio del miglior modello Logistic Regression
save_model(best_lr_model, "best_lr_model.pkl")
# Out:
# Risultati salvati con successo in: ../results/lr_results.csv
# Errore nel salvataggio del modello: [Errno 2] No such file or directory: './models/best_lr_model.pkl'

# %% [markdown]
# ### Random Forest

# %%
# Creazione il modello Random Forest
rf = RandomForestClassifier(random_state=42)

# Definisco la griglia di iperparametri
param_grid = {
    'n_estimators': [100, 200],          # Numero di alberi (limitato a 100 e 200)
    'max_depth': [3, 5],                # Profondità massima (limitato a 10 e 20)
    'min_samples_leaf': [1, 2],          # Minimo numero di campioni per una foglia (limitato a 1 e 2)
}

# Grid Search
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring='f1_weighted',  # Ottimizzare per F1-score ponderato
    cv=5,
    n_jobs=-1,
    verbose=2
)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [5, 7], 'min_samples_leaf': [1, 2],
#                          'n_estimators': [100, 200]},
#              scoring='f1_weighted', verbose=2)

# %%
# Individuo il  Miglior modello trovato
print("Migliori parametri trovati: ", grid_search.best_params_)
best_rf_model = grid_search.best_estimator_
# Out:
# Migliori parametri trovati:  {'max_depth': 7, 'min_samples_leaf': 1, 'n_estimators': 200}

# %%
# Predico sul set di test
y_pred = best_rf_model.predict(X_test)

#  Report di classificazione
print("Classification report on test set:")
print(classification_report(y_test, y_pred))
# Out:
# Classification report on test set:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.83      0.90    165850
#          1.0       0.21      0.83      0.34      9293
#
#     accuracy                           0.83    175143
#    macro avg       0.60      0.83      0.62    175143
# weighted avg       0.95      0.83      0.87    175143

# %%
#  Matrice di confusione
plot_confusion_matrix(y_test, y_pred)

# %%
#Salvataggio dei risultati
columns_to_save = [
    'param_n_estimators', 'param_max_depth', 'param_min_samples_leaf',  # Parametri del modello
    'mean_test_score', 'std_test_score', 'rank_test_score', 'precision', 'recall', 'f1_score', 'accuracy' #metrics
]

results = pd.DataFrame(grid_search.cv_results_)
results['precision'] = precision_score(y_test, y_pred, average='weighted')
results['recall'] = recall_score(y_test, y_pred, average='weighted')
results['f1_score'] = f1_score(y_test, y_pred, average='weighted')
results['accuracy'] = accuracy_score(y_test, y_pred)

save_grid_search_results(results, columns_to_save, 'rf_results.csv')

# Salvataggio del miglior modello RF
save_model(best_rf_model, "best_rf_model.pkl")
# Out:
# Risultati salvati con successo in: ../results/rf_results.csv
# Errore nel salvataggio del modello: [Errno 2] No such file or directory: './models/best_rf_model.pkl'

# %% [markdown]
# ### XGBoost

# %%
# Creo del modello XGBoost
model = XGBClassifier(
    objective='binary:logistic',  # Per classificazione multiclasse
    random_state=42,
    eval_metric='logloss'      # Specifica la metrica di valutazione
)

# Definizione della griglia di iperparametri
param_grid = {
    'n_estimators': [100, 200],           # Numero di boosting rounds
    'learning_rate': [0.01, 0.1],         # Step size (limitato a 0.01 e 0.1)
    'max_depth': [3, 5],                   # Profondità massima dell'albero (limitato a 3 e 5)
    'subsample': [0.8, 1.0],               # Sottocampione dei dati (limitato a 0.8 e 1.0)
}

#  Grid Search
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    scoring='f1_weighted',  # Ottimizzare per F1-score ponderato
    cv=5,
    n_jobs=-1,
    verbose=2
)
grid_search.fit(X_train, y_train)

# Miglior modello
print("Migliori parametri trovati: ", grid_search.best_params_)
best_xgb_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Migliori parametri trovati:  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200, 'subsample': 0.8}

# %%
#  Predizioni sul set di test
y_pred = best_xgb_model.predict(X_test)

# Report di classificazione
print("Classification report on test set:")
print(classification_report(y_test, y_pred))
# Out:
# Classification report on test set:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.98    165850
#          1.0       0.64      0.93      0.76      9293
#
#     accuracy                           0.97    175143
#    macro avg       0.82      0.95      0.87    175143
# weighted avg       0.98      0.97      0.97    175143

# %%
#plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
#Salvataggio dei risultati
columns_to_save = [
    'param_n_estimators', 'param_learning_rate', 'param_max_depth',
    'param_subsample',
    'mean_test_score', 'std_test_score', 'rank_test_score', 'precision', 'recall', 'f1_score', 'accuracy'
]

results = pd.DataFrame(grid_search.cv_results_)
results['precision'] = precision_score(y_test, y_pred, average='weighted')
results['recall'] = recall_score(y_test, y_pred, average='weighted')
results['f1_score'] = f1_score(y_test, y_pred, average='weighted')
results['accuracy'] = accuracy_score(y_test, y_pred)

save_grid_search_results(results, columns_to_save, 'xgb_results.csv')

# Salvataggio del miglior modello XGBoost
save_model(best_xgb_model, "best_xgb_model.pkl")
# Out:
# Risultati salvati con successo in: ../results/xgb_results.csv
# Errore nel salvataggio del modello: [Errno 2] No such file or directory: './models/best_xgb_model.pkl'

# %% [markdown]
# ## SHAP

# %%
X_test.shape
# Out:
# (175143, 29)

# %%
best_rf_model = pickle.load(open('../models/best_rf_model.pkl', 'rb'))

# %%
plot_feature_importance(best_rf_model, pca, pd.DataFrame(X_test_copy))

# %%
# compute SHAP values
#LOAD MODEL FROM PICKLE
explainer = shap.TreeExplainer(best_rf_model, pd.DataFrame(X_train[1000]))
shap_values = explainer(pd.DataFrame(X_test[1000]), check_additivity= False)

# %%
pca_loadings = pca.components_.T  # Trasponiamo i loadings di PCA per allinearli con le feature originali
shap_values_original_features = shap_values[1] @ pca_loadings  # Moltiplichiamo i valori SHAP con i loadings

# Step 6: Visualizza il grafico SHAP usando le feature originali
# Mostra i contributi delle feature originali invece che delle componenti principali
shap.summary_plot(shap_values_original_features, X_test, feature_names=X.columns)

# %%
#shap_values_explanation = shap.Explanation(values=shap_values, base_values=np.zeros_like(shap_values), data=X_test)

# %%
class_names = ['0','1']
for i, class_name in enumerate(class_names):
    shap.summary_plot(shap_values[:,:,i], pd.DataFrame(X_test).values, plot_type='bar',
                      class_names=class_names, feature_names=pd.DataFrame(X_test).columns.tolist())
